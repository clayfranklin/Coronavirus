# %%
import pandas as pd
import datetime
import time

# %%
date = datetime.datetime.today()
date_modify = str(date)
date_to_add = date_modify[0:10]

# %%
daily = "https://www.tn.gov/health/cedep/ncov.html"
viral = pd.read_html(daily)
df2 = viral[5]
TN_county = df2[:-3]
TN_county.loc[:,'Date']=date_to_add
TN_county["County"] = TN_county.loc[:, ('County')].str.split(" County", expand = True)
TN_county
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-b89065e9ed69> in <module>
#       1 daily = "https://www.tn.gov/health/cedep/ncov.html"
# ----> 2 viral = pd.read_html(daily)
#       3 df2 = viral[5]
#       4 TN_county = df2[:-3]
#       5 TN_county.loc[:,'Date']=date_to_add
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
#     911     else:
# --> 912         raise_with_traceback(retained)
#     913
#     914     ret = []
#
# ~\Anaconda3\lib\site-packages\pandas\compat\__init__.py in raise_with_traceback(exc, traceback)
#      45     if traceback == Ellipsis:
#      46         _, _, traceback = sys.exc_info()
# ---> 47     raise exc.with_traceback(traceback)
#      48
#      49
#
# ValueError: No tables found

# %%
url2="https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv"
viral_times=pd.read_csv(url2)
viral_times
# Out:
#               date      county       state     fips  cases  deaths
# 0       2020-01-21   Snohomish  Washington  53061.0      1       0
# 1       2020-01-22   Snohomish  Washington  53061.0      1       0
# 2       2020-01-23   Snohomish  Washington  53061.0      1       0
# 3       2020-01-24        Cook    Illinois  17031.0      1       0
# 4       2020-01-24   Snohomish  Washington  53061.0      1       0
# ...            ...         ...         ...      ...    ...     ...
# 264115  2020-06-23  Sweetwater     Wyoming  56037.0     58       0
# 264116  2020-06-23       Teton     Wyoming  56039.0    113       1
# 264117  2020-06-23       Uinta     Wyoming  56041.0    152       0
# 264118  2020-06-23    Washakie     Wyoming  56043.0     38       5
# 264119  2020-06-23      Weston     Wyoming  56045.0      1       0
#
# [264120 rows x 6 columns]

# %%
viral_times.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264120 entries, 0 to 264119
# Data columns (total 6 columns):
# date      264120 non-null object
# county    264120 non-null object
# state     264120 non-null object
# fips      261364 non-null float64
# cases     264120 non-null int64
# deaths    264120 non-null int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 12.1+ MB

# %%
TN=viral_times[viral_times["county"] == 'Davidson']
TN
# Out:
#               date    county           state     fips  cases  deaths
# 841     2020-03-08  Davidson       Tennessee  47037.0      1       0
# 970     2020-03-09  Davidson       Tennessee  47037.0      1       0
# 1127    2020-03-10  Davidson       Tennessee  47037.0      1       0
# 1323    2020-03-11  Davidson       Tennessee  47037.0      2       0
# 1569    2020-03-12  Davidson       Tennessee  47037.0      6       0
# ...            ...       ...             ...      ...    ...     ...
# 257343  2020-06-21  Davidson       Tennessee  47037.0   8052      95
# 259874  2020-06-22  Davidson  North Carolina  37057.0    759      15
# 260390  2020-06-22  Davidson       Tennessee  47037.0   8191      96
# 262923  2020-06-23  Davidson  North Carolina  37057.0    772      15
# 263439  2020-06-23  Davidson       Tennessee  47037.0   8258      98
#
# [204 rows x 6 columns]

# %%
TN_today=pd.concat([TN_Depth_Health,TN_county], join='outer', sort=True)
TN_today
# TN_cases.to_csv("C:/Users/clayf/Documents/Coronavirus/Covid_predictions/TN/Resources/Synched/TNDepthHealth_" + date_to_add + '_today.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-7af4a8a009e1> in <module>
# ----> 1 TN_today=pd.concat([TN_Depth_Health,TN_county], join='outer', sort=True)
#       2 TN_today
#       3 # TN_cases.to_csv("C:/Users/clayf/Documents/Coronavirus/Covid_predictions/TN/Resources/Synched/TNDepthHealth_" + date_to_add + '_today.csv')
#
# NameError: name 'TN_Depth_Health' is not defined

# %%
TN_Depth_Health = pd.read_csv("C:/Users/clayf/Documents/Coronavirus/Covid_predictions/TN/Resources/TNDepthHealth" + date_to_add + '_today.csv')
TN_today=pd.concat([TN_Depth_Health,TN_county], join='outer', sort=True)
TN_today=TN_today.sort_values('County')
TN_today.to_csv("C:/Users/clayf/Documents/Coronavirus/Covid_predictions/TN/Resources/Synched" + date_to_add +'_today.csv',index=False)
time.sleep = (10.03)
url2="https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv"
viral_times=pd.read_csv(url2)
TN=viral_times[viral_times["state"] == 'Tennessee']
TN=TN.rename(columns={'county':'County'})
TN=TN.rename(columns={'date':'Date'})
TN=TN.rename(columns={'cases':'Positive'})
TN=TN.rename(columns={'deaths':'Death'})
TN=TN.drop(['state'], axis=1)

TN_for_update=pd.read_csv("C:/Users/clayf/Documents/Coronavirus/Covid_predictions/TN/Resources/Synched" + date_to_add +'today.csv')
Synched=TN.append(TN_for_update, sort=True)
TN_cases=Synched.sort_values(["County", "Date"],ascending=[0,1])
TN_cases["Duplicates"]=TN_cases["County"]+TN_cases['Date']
TN_cases = TN_cases.drop_duplicates(subset="Duplicates", keep="last")
TN_cases=TN_cases.drop(['Duplicates'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-81cf5f0579eb> in <module>
# ----> 1 TN_Depth_Health = pd.read_csv("C:/Users/clayf/Documents/Coronavirus/Covid_predictions/TN/Resources/TNDepthHealth" + date_to_add + '_today.csv')
#       2 TN_today=pd.concat([TN_Depth_Health,TN_county], join='outer', sort=True)
#       3 TN_today=TN_today.sort_values('County')
#       4 TN_today.to_csv("C:/Users/clayf/Documents/Coronavirus/Covid_predictions/TN/Resources/Synched" + date_to_add +'_today.csv',index=False)
#       5 time.sleep = (10.03)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'C:/Users/clayf/Documents/Coronavirus/Covid_predictions/TN/Resources/TNDepthHealth2020-05-21_today.csv' does not exist: b'C:/Users/clayf/Documents/Coronavirus/Covid_predictions/TN/Resources/TNDepthHealth2020-05-21_today.csv'

# %%
# TN_x.to_csv('C:/Users/clayf/Documents/Coronavirus/Covid_predictions/TN/Resources/TNDepthHealth.csv',index=False)

# %%
TN_cases=TN_cases.drop(['Duplicates'],axis=1)
TN_cases
# Out:
#              County        Date  Death  Negative  Percent_Tested  \
# 94    Wilson County  2020-04-02    NaN     756.0             NaN
# 5041         Wilson  2020-03-19    0.0       NaN             NaN
# 5930         Wilson  2020-03-20    0.0       NaN             NaN
# 6947         Wilson  2020-03-21    0.0       NaN             NaN
# 8077         Wilson  2020-03-22    0.0       NaN             NaN
# ...             ...         ...    ...       ...             ...
# 44         Anderson  2020-03-28    NaN       NaN             NaN
# 89         Anderson  2020-03-29    NaN       NaN             NaN
# 154        Anderson  2020-03-30    NaN       NaN             NaN
# 228        Anderson  2020-03-31    NaN     129.0             0.2
# 322        Anderson  2020-04-01    NaN     135.0             0.2
#
#       Percentage of County Population  Population  Positive     fips
# 94                                NaN         NaN      62.0      NaN
# 5041                              NaN         NaN       2.0  47189.0
# 5930                              NaN         NaN       3.0  47189.0
# 6947                              NaN         NaN       3.0  47189.0
# 8077                              NaN         NaN       3.0  47189.0
# ...                               ...         ...       ...      ...
# 44                              0.006     76978.0       5.0      NaN
# 89                              0.008     76978.0       6.0      NaN
# 154                             0.012     76978.0       9.0      NaN
# 228                             0.013     76978.0      10.0      NaN
# 322                             0.013     76978.0      10.0      NaN
#
# [974 rows x 9 columns]

# %%
url="https://www.nytimes.com/interactive/2020/us/coronavirus-us-cases.html"
viralNYT=pd.read_html(url)
US_counties = viralNYT[2]
US_counties
# Out:
#                                   Cases Connected To  Cases
# 0     Marion Correctional Institution — Marion, Ohio   2439
# 1  Pickaway Correctional Institution — Scioto Tow...   1791
# 2  Trousdale Turner Correctional Center — Hartsvi...   1308
# 3  Smithfield Foods pork processing facility — Si...   1095
# 4     Tyson Foods meatpacking plant — Waterloo, Iowa   1031
# 5             Lompoc Prison Complex — Lompoc, Calif.   1020
# 6                   Cook County jail — Chicago, Ill.   1018
# 7                   U.S.S. Theodore Roosevelt — Guam    969
# 8                  Cummins Unit prison — Grady, Ark.    960
# 9                Harris County jail — Houston, Texas    947

# %%
url2="https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-counties.csv"
viral_times=pd.read_csv(url2)
TN=viral_times[viral_times["state"] == 'Tennessee']
TN=TN.rename(columns={'county':'County'})
TN=TN.rename(columns={'date':'Date'})
TN=TN.rename(columns={'cases':'Positive'})
TN=TN.rename(columns={'deaths':'Death'})
TN=TN.drop(['state'], axis=1)
TN.to_csv('C:/Users/clayf/Documents/Coronavirus/Covid_predictions/TN/Resources/NYtimes_historical.csv',index=False)
TN
# Out:
#               Date      County     fips  Positive  Death
# 570     2020-03-05  Williamson  47187.0         1      0
# 639     2020-03-06  Williamson  47187.0         1      0
# 731     2020-03-07  Williamson  47187.0         1      0
# 841     2020-03-08    Davidson  47037.0         1      0
# 842     2020-03-08      Shelby  47157.0         1      0
# ...            ...         ...      ...       ...    ...
# 161346  2020-05-20       Wayne  47181.0        63      0
# 161347  2020-05-20     Weakley  47183.0        27      0
# 161348  2020-05-20       White  47185.0        21      0
# 161349  2020-05-20  Williamson  47187.0       492     10
# 161350  2020-05-20      Wilson  47189.0       338      8
#
# [5358 rows x 5 columns]

# %%
Synched=TN.append(TN_today, sort=True)
TN_cases=Synched.sort_values(["County", "Date"],ascending=[0,1])
TN_cases["Duplicates"]=TN_cases["County"]+TN_cases['Date']
TN_cases = TN_cases.drop_duplicates(subset="Duplicates", keep="last")
TN_cases
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a0421ec166dc> in <module>
# ----> 1 Synched=TN.append(TN_today, sort=True)
#       2 TN_cases=Synched.sort_values(["County", "Date"],ascending=[0,1])
#       3 TN_cases["Duplicates"]=TN_cases["County"]+TN_cases['Date']
#       4 TN_cases = TN_cases.drop_duplicates(subset="Duplicates", keep="last")
#       5 TN_cases
#
# NameError: name 'TN_today' is not defined

# %%
TN_deaths = TN_x.merge(TN,left_on='Date',right_on='County', how='outer')

TN_deaths
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-17953c21b588> in <module>
# ----> 1 TN_deaths = TN_x.merge(TN,left_on='Date',right_on='County', how='outer')
#       2
#       3 TN_deaths
#
# NameError: name 'TN_x' is not defined

# %%
TN_stuff=pd.concat([TN_x,TN], join='left')
TN_stuff.head(50)
