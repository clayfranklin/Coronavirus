# %%
import pandas as pd

# %%
TN=pd.read_excel("C:/Users/clayf/Downloads/Public-Dataset-County-New.xlsx")
TN["DATE"]=TN["DATE"].astype(str)
TN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10753 entries, 0 to 10752
# Data columns (total 20 columns):
# DATE                  10753 non-null object
# COUNTY                10753 non-null object
# TOTAL_CASES           10591 non-null float64
# NEW_CASES             10493 non-null float64
# TOTAL_CONFIRMED       6596 non-null float64
# NEW_CONFIRMED         6499 non-null float64
# TOTAL_PROBABLE        6596 non-null float64
# NEW_PROBABLE          6499 non-null float64
# POS_TESTS             9894 non-null float64
# NEG_TESTS             9894 non-null float64
# TOTAL_TESTS           9894 non-null float64
# NEW_TESTS             9797 non-null float64
# NEW_DEATHS            9700 non-null float64
# TOTAL_DEATHS          9797 non-null float64
# NEW_RECOVERED         8827 non-null float64
# TOTAL_RECOVERED       8924 non-null float64
# NEW_ACTIVE            9797 non-null float64
# TOTAL_ACTIVE          9894 non-null float64
# NEW_HOSPITALIZED      7178 non-null float64
# ...

# %%
Sumner=TN[TN["COUNTY"] == "Sumner"]
Sumner
# Out:
#              DATE  COUNTY  TOTAL_CASES  NEW_CASES  TOTAL_CONFIRMED  \
# 43     2020-03-13  Sumner          NaN        NaN              NaN
# 57     2020-03-14  Sumner          NaN        NaN              NaN
# 68     2020-03-15  Sumner          NaN        NaN              NaN
# 91     2020-03-16  Sumner          NaN        NaN              NaN
# 121    2020-03-17  Sumner          NaN        NaN              NaN
# ...           ...     ...          ...        ...              ...
# 10352  2020-07-07  Sumner       1670.0       34.0           1660.0
# 10449  2020-07-08  Sumner       1727.0       57.0           1717.0
# 10546  2020-07-09  Sumner       1802.0       75.0           1792.0
# 10643  2020-07-10  Sumner       1874.0       72.0           1864.0
# 10740  2020-07-11  Sumner       1897.0       23.0           1887.0
#
#        NEW_CONFIRMED  TOTAL_PROBABLE  NEW_PROBABLE  POS_TESTS  NEG_TESTS  \
# 43               NaN             NaN           NaN        NaN        NaN
# ...

# %%
Age=pd.read_excel("C:/Users/clayf/Downloads/Public-Dataset-Daily-County-Age-Group.XLSX")
SumnerAge=Age[Age["COUNTY"] == "Sumner"]
SumnerAge
# Out:
#             DATE  COUNTY    AGE_GROUP  CASE_COUNT
# 630   2020-06-12  Sumner   0-10 years          27
# 631   2020-06-12  Sumner  11-20 years          86
# 632   2020-06-12  Sumner  21-30 years         156
# 633   2020-06-12  Sumner  31-40 years         177
# 634   2020-06-12  Sumner  41-50 years         168
# ...          ...     ...          ...         ...
# 11399 2020-06-27  Sumner  51-60 years         201
# 11400 2020-06-27  Sumner  61-70 years         114
# 11401 2020-06-27  Sumner  71-80 years          91
# 11402 2020-06-27  Sumner    81+ years          86
# 11403 2020-06-27  Sumner      Pending          11
#
# [150 rows x 4 columns]

# %%
Sumner.to_csv('C:/Users/clayf/Documents/Coronavirus/Covid_predictions/TN/Resources/Sumner.csv',index=False)
