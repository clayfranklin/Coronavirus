# %%
import pandas as pd

# %%
TN=pd.read_excel("C:/Users/clayf/Downloads/Public-Dataset-County-New.xlsx")
TN
# Out:
#             DATE      COUNTY  TOTAL_CASES  NEW_CASES  TOTAL_CONFIRMED  \
# 0     2020-03-05      Shelby          NaN        NaN              NaN
# 1     2020-03-05  Williamson          1.0        NaN              NaN
# 2     2020-03-06    Davidson          NaN        NaN              NaN
# 3     2020-03-06  Williamson          1.0        0.0              NaN
# 4     2020-03-07  Williamson          1.0        0.0              NaN
# ...          ...         ...          ...        ...              ...
# 10748 2020-07-11       Wayne        115.0        5.0            115.0
# 10749 2020-07-11     Weakley         70.0        1.0             69.0
# 10750 2020-07-11       White         85.0        4.0             84.0
# 10751 2020-07-11  Williamson       1708.0       38.0           1705.0
# 10752 2020-07-11      Wilson       1148.0       18.0           1146.0
#
#        NEW_CONFIRMED  TOTAL_PROBABLE  NEW_PROBABLE  POS_TESTS  NEG_TESTS  \
# ...

# %%
TNpop = pd.read_csv("Population Estimates by County.csv")
TNpop= TNpop.drop([96])
TNpop = TNpop.drop([0])
TNpop["Population Estimates by County"]= TNpop["Population Estimates by County"].str.split(" County", n = 1, expand = True)
TNpop = TNpop.rename(columns={'Population Estimates by County': 'County'})
TN_county_populations = TNpop.rename(columns={'Unnamed: 1': 'Population'})
TN_county_populations["Population"] = TN_county_populations["Population"].str.replace(",","").astype(int)
TN_county_populations
# Out:
#         County  Population
# 1     Anderson       76978
# 2      Bedford       49713
# 3       Benton       16160
# 4      Bledsoe       15064
# 5       Blount      133088
# ..         ...         ...
# 91       Wayne       16673
# 92     Weakley       33328
# 93       White       27345
# 94  Williamson      238412
# 95      Wilson      144657
#
# [95 rows x 2 columns]

# %%
TN_data = TN_county_populations.merge(TN,left_on='County',right_on='COUNTY', how='left')
TN_data.head(60)
# Out:
#       County  Population       DATE    COUNTY  TOTAL_CASES  NEW_CASES  \
# 0   Anderson       76978 2020-03-13  Anderson          NaN        NaN
# 1   Anderson       76978 2020-03-18  Anderson          NaN        NaN
# 2   Anderson       76978 2020-03-20  Anderson          1.0        NaN
# 3   Anderson       76978 2020-03-21  Anderson          1.0        0.0
# 4   Anderson       76978 2020-03-22  Anderson          1.0        0.0
# 5   Anderson       76978 2020-03-23  Anderson          1.0        0.0
# 6   Anderson       76978 2020-03-24  Anderson          1.0        0.0
# 7   Anderson       76978 2020-03-25  Anderson          3.0        2.0
# 8   Anderson       76978 2020-03-26  Anderson          3.0        0.0
# 9   Anderson       76978 2020-03-27  Anderson          4.0        1.0
# 10  Anderson       76978 2020-03-28  Anderson          5.0        1.0
# 11  Anderson       76978 2020-03-29  Anderson          6.0        1.0
# ...

# %%
TN_data["Percentage of County Population"] = round((TN_data["NEW_ACTIVE"]/TN_data["Population"])*100,3)
TN_data["Percent_Tested"] = round((TN_data["TOTAL_TESTS"]/TN_data["Population"])*100,1)
TN_data
# Out:
#          County  Population       DATE    COUNTY  TOTAL_CASES  NEW_CASES  \
# 0      Anderson       76978 2020-03-13  Anderson          NaN        NaN
# 1      Anderson       76978 2020-03-18  Anderson          NaN        NaN
# 2      Anderson       76978 2020-03-20  Anderson          1.0        NaN
# 3      Anderson       76978 2020-03-21  Anderson          1.0        0.0
# 4      Anderson       76978 2020-03-22  Anderson          1.0        0.0
# ...         ...         ...        ...       ...          ...        ...
# 10304    Wilson      144657 2020-07-07    Wilson        999.0       36.0
# 10305    Wilson      144657 2020-07-08    Wilson       1060.0       61.0
# 10306    Wilson      144657 2020-07-09    Wilson       1099.0       39.0
# 10307    Wilson      144657 2020-07-10    Wilson       1130.0       31.0
# 10308    Wilson      144657 2020-07-11    Wilson       1148.0       18.0
#
#        TOTAL_CONFIRMED  NEW_CONFIRMED  TOTAL_PROBABLE  NEW_PROBABLE  ...  \
# ...

# %%
TN_data.to_csv("C:/Users/clayf/Documents/Coronavirus/Covid_predictions/TN/Resources/Merged_TN_DATA.csv", index=False, encoding ="UTF-8")
